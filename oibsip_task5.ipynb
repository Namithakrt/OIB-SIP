# %% [markdown]
# <a href="https://colab.research.google.com/github/Namithakrt/OIB-SIP/blob/main/oibsip_task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/Advertising.csv")
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.shape
# Out:
# (200, 5)

# %%
df.size
# Out:
# 1000

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
df=df.drop('Unnamed: 0',axis=1)
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
x=df.iloc[:,:-1]
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 169  284.3   10.6        6.4
# 97   184.9   21.0       22.0
# 31   112.9   17.4       38.6
# 12    23.8   35.1       65.9
# 35   290.7    4.1        8.5
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [140 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 95   163.3   31.6       52.9
# 15   195.4   47.7       52.9
# 30   292.9   28.3       43.2
# 158   11.7   36.9       45.2
# 128  220.3   49.0        3.2
# 115   75.1   35.0       52.7
# 69   216.8   43.9       27.2
# 170   50.0   11.6       18.4
# 174  222.4    3.4       13.1
# 45   175.1   22.5       31.5
# 66    31.5   24.6        2.2
# 182   56.2    5.7       29.7
# 165  234.5    3.4       84.8
# 78     5.4   29.9        9.4
# 186  139.5    2.1       26.6
# 177  170.2    7.8       35.2
# 56     7.3   28.1       41.4
# 152  197.6   23.3       14.2
# 82    75.3   20.3       32.5
# 68   237.4   27.5       11.0
# 124  229.5   32.3       74.2
# 16    67.8   36.6      114.0
# 148   38.0   40.3       11.9
# 93   250.9   36.5       72.3
# 65    69.0    9.3        0.9
# 60    53.5    2.0       21.4
# 84   213.5   43.0       33.8
# 67   139.3   14.5       10.2
# 125   87.2   11.8       25.9
# 132    8.4   27.2        2.1
# 9    199.8    2.6       21.2
# ...

# %%
y_train
# Out:
# 169    15.0
# 97     15.5
# 31     11.9
# 12      9.2
# 35     12.8
#        ...
# 106     7.2
# 14     19.0
# 92     19.4
# 179    12.6
# 102    14.8
# Name: Sales, Length: 140, dtype: float64

# %%
y_test
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    11.5
# 45     14.9
# 66      9.5
# 182     8.7
# 165    11.9
# 78      5.3
# 186    10.3
# 177    11.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65      9.3
# 60      8.1
# 84     21.7
# 67     13.4
# 125    10.6
# 132     5.7
# 9      10.6
# 18     11.3
# 55     23.7
# 75      8.7
# 150    16.1
# 104    20.7
# 135    11.6
# 137    20.8
# 164    11.9
# 76      6.9
# 79     11.0
# 197    12.8
# 38     10.1
# 24      9.7
# 122    11.6
# 195     7.6
# 29     10.5
# 19     14.6
# 143    10.4
# 86     12.0
# 114    14.6
# 173    11.7
# 5       7.2
# 126     6.6
# 117     9.4
# 73     11.0
# 140    10.9
# 98     25.4
# 172     7.6
# 96     11.7
# Name: Sales, dtype: float64

# %%
import seaborn as sns

# %%
sns.regplot(x=df['Newspaper'],y=y,color='r')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
sns.regplot(x=df['Radio'],y=y,color='b')
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.regplot(x=df['TV'],y=y,color='c')
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([17.9489591 , 22.37455048, 22.79211282, 12.44480854, 23.39042071,
#        14.83197855, 22.41429453,  9.11687693, 14.88087711, 16.59840646,
#        10.70062224,  8.32770263, 15.81930785, 10.63623577, 11.17830817,
#        13.62036299, 10.56405044, 17.60788591, 11.9306182 , 20.08370877,
#        21.03046413, 15.18558856, 14.01570051, 22.72927318,  9.38736665,
#         7.46119419, 22.14157907, 13.42736996, 10.7854383 , 10.20855266,
#        13.812931  , 11.62479347, 22.88839367, 14.21798925, 19.50138949,
#        21.37526272, 15.70694939, 22.18444764, 12.49460149,  6.27235101,
#        11.2187167 , 14.02545825, 11.78783597,  9.83068029, 14.77398255,
#         7.0867009 , 10.96270525, 15.60561131, 10.41942346, 13.24301495,
#        17.09725145, 13.27873206, 14.77071021, 12.69001793,  8.17105955,
#        11.45876216, 11.10759395, 25.36076159,  9.42598722, 13.79984117])

# %%
print("slope=",model.coef_)
# Out:
# slope= [3.68334078 2.90625242 0.14194772]

# %%
list(zip(x,model.coef_))
# Out:
# [('TV', 3.6833407810865872),
#  ('Radio', 2.9062524207719314),
#  ('Newspaper', 0.14194771902905545)]

# %%
print('constant=',model.intercept_)
# Out:
# constant= 14.497142857142858

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
print("mae=",mean_absolute_error(y_test,y_pred))
print("mape=",mean_absolute_percentage_error(y_test,y_pred))
print("mse=",mean_squared_error(y_test,y_pred))
# Out:
# mae= 1.7677050331419961
# mape= 0.1913662894616395
# mse= 6.209703302450422

# %%
x=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(x)

# %%
print("r2 score=",r2_score(y_test,y_pred))
# Out:
# r2 score= 0.7725767303950064
