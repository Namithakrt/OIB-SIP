# %% [markdown]
# <a href="https://colab.research.google.com/github/Namithakrt/OIB-SIP/blob/main/oibsip_task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/car data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Selling_type Transmission  Owner
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0

# %%
df.size
# Out:
# 2709

# %%
df.shape
# Out:
# (301, 9)

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 17    ertiga  2016           7.75          10.79       43000    Diesel
# 93  fortuner  2015          23.00          30.61       40000    Diesel
#
#    Selling_type Transmission  Owner
# 17       Dealer       Manual      0
# 93       Dealer    Automatic      0

# %%
df=df.drop_duplicates()
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [299 rows x 9 columns]

# %%
import seaborn as sns
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.regplot(x=df['Year'],y=df['Selling_Price'],color='r')
# Out:
# <Axes: xlabel='Year', ylabel='Selling_Price'>

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df['Car_Name']=label.fit_transform(df['Car_Name'])
df['Fuel_Type']=label.fit_transform(df['Fuel_Type'])
df['Selling_type']=label.fit_transform(df['Selling_type'])
df['Transmission']=label.fit_transform(df['Transmission'])
# Out:
# <ipython-input-11-536acac663c0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Car_Name']=label.fit_transform(df['Car_Name'])
# <ipython-input-11-536acac663c0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Fuel_Type']=label.fit_transform(df['Fuel_Type'])
# <ipython-input-11-536acac663c0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Selling_type']=label.fit_transform(df['Selling_type'])
# <ipython-input-11-536acac663c0>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Transmission']=label.fit_transform(df['Transmission'])

# %%
x=df.drop(['Selling_Price'],axis=1)
x
# Out:
#      Car_Name  Year  Present_Price  Driven_kms  Fuel_Type  Selling_type  \
# 0          90  2014           5.59       27000          2             0
# 1          93  2013           9.54       43000          1             0
# 2          68  2017           9.85        6900          2             0
# 3          96  2011           4.15        5200          2             0
# 4          92  2014           6.87       42450          1             0
# ..        ...   ...            ...         ...        ...           ...
# 296        69  2016          11.60       33988          1             0
# 297        66  2015           5.90       60000          2             0
# 298        69  2009          11.00       87934          2             0
# 299        69  2017          12.50        9000          1             0
# 300        66  2016           5.90        5464          2             0
#
#      Transmission  Owner
# 0               1      0
# 1               1      0
# 2               1      0
# 3               1      0
# 4               1      0
# ..            ...    ...
# 296             1      0
# 297             1      0
# 298             1      0
# 299             1      0
# 300             1      0
#
# [299 rows x 8 columns]

# %%
y=df['Selling_Price']
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 299, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x)
# Out:
# StandardScaler()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
x_train
# Out:
#      Car_Name  Year  Present_Price  Driven_kms  Fuel_Type  Selling_type  \
# 226        82  2015           5.70       24678          2             0
# 69         71  2016          20.91       12000          2             0
# 224        94  2013           9.40       36198          2             0
# 38         63  2016           3.76       10079          2             0
# 16         76  2015          10.79       41678          1             0
# ..        ...   ...            ...         ...        ...           ...
# 190        14  2008           0.75       60000          2             1
# 72         71  2013          18.61       56001          2             0
# 108        48  2016           1.50       18000          2             1
# 272        69  2015          10.00       27600          2             0
# 104        46  2017           1.47        4100          2             1
#
#      Transmission  Owner
# 226             1      0
# 69              1      0
# 224             0      0
# 38              1      0
# 16              1      0
# ..            ...    ...
# 190             1      0
# 72              1      0
# 108             1      0
# 272             1      0
# 104             1      0
#
# [209 rows x 8 columns]

# %%
x_test
# Out:
#      Car_Name  Year  Present_Price  Driven_kms  Fuel_Type  Selling_type  \
# 283        69  2016          11.80        9010          2             0
# 267        69  2016           9.40       19434          1             0
# 166        25  2016           0.55        1000          2             1
# 9          68  2015           8.92       42367          1             0
# 78         71  2010          22.83       80000          2             0
# ..        ...   ...            ...         ...        ...           ...
# 134        51  2017           0.81       11800          2             1
# 73         80  2011           5.71       43000          2             0
# 15         76  2016          10.79       43000          1             0
# 10         62  2017           3.60        2135          2             0
# 159        31  2017           0.51        4000          2             1
#
#      Transmission  Owner
# 283             1      0
# 267             1      0
# 166             1      0
# 9               1      0
# 78              0      0
# ..            ...    ...
# 134             1      0
# 73              1      0
# 15              1      0
# 10              1      0
# 159             0      0
#
# [90 rows x 8 columns]

# %%
y_train
# Out:
# 226     5.25
# 69     14.25
# 224     5.11
# 38      3.00
# 16      7.25
#        ...
# 190     0.20
# 72      7.45
# 108     1.20
# 272     7.50
# 104     1.35
# Name: Selling_Price, Length: 209, dtype: float64

# %%
y_test
# Out:
# 283    8.99
# 267    8.35
# 166    0.45
# 9      7.45
# 78     5.25
#        ...
# 134    0.65
# 73     2.65
# 15     7.75
# 10     2.85
# 159    0.45
# Name: Selling_Price, Length: 90, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 7.46472652,  7.35416662,  1.25687554,  6.58460671, 11.49812624,
#         4.45681814,  8.52917997,  1.80011183,  8.60753275, -1.04917964,
#         9.97092816, -1.01563953,  1.12511597,  1.70738507,  5.22149389,
#         5.10468048,  1.1352747 ,  1.89633326, 21.57342197,  1.06042601,
#         1.14013752,  2.66768991,  5.67662647,  0.39821796,  5.87556941,
#         7.79626854,  8.29343849,  1.27043572,  5.00630725,  5.13159295,
#         6.24078196,  5.90401091,  5.88261257,  2.855591  ,  3.0791058 ,
#         6.72499313,  1.3471881 , -4.33722008,  1.48469076, 10.70836818,
#         7.14735028,  8.77010448,  1.45800655,  4.33169273,  1.1594846 ,
#        -2.2208542 ,  8.15702793,  4.27505328,  6.03113947, -0.68354276,
#         0.5053941 ,  0.04829097, 11.46881952,  9.07432965,  7.28733832,
#         5.95542139,  3.78545084,  3.61113087,  9.20180459,  9.16139257,
#         5.40921742,  0.60385162,  0.02320464, -1.11397778,  2.4858576 ,
#         2.73870815,  7.88867714,  8.01056321,  2.7748664 ,  6.75076329,
#         1.78213173,  6.30627701,  7.99007586,  7.62882194, -0.63627102,
#         2.19907639, 16.64066151,  9.88987764,  3.99800104, -1.8872963 ,
#        -0.12482723,  3.82346224,  0.39302819,  9.74886315,  9.398511  ,
#         1.83804427,  2.86182374,  7.81110103,  4.21105155,  3.48189445])

# %%
list(zip(x,model.coef_))
# Out:
# [('Car_Name', 0.008511118355606802),
#  ('Year', 0.34327149192641043),
#  ('Present_Price', 0.4389570442298373),
#  ('Driven_kms', -9.029691784567806e-06),
#  ('Fuel_Type', -1.0370625191127534),
#  ('Selling_type', -0.9674228500684565),
#  ('Transmission', -1.8753280631240843),
#  ('Owner', 0.8366753715721872)]

# %%
print("constant is",model.intercept_)
# Out:
# constant is -686.306750870871

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
print("mae=",mean_absolute_error(y_test,y_pred))
print("mape=",mean_absolute_percentage_error(y_test,y_pred))
print("mse=",mean_squared_error(y_test,y_pred))
# Out:
# mae= 1.4586612385559596
# mape= 1.3919294014480705
# mse= 5.6055346051850705

# %%
x=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(x)
print(rmse)
# Out:
# 2.3676010232269014

# %%
print("r2_score=",r2_score(y_test,y_pred))
# Out:
# r2_score= 0.7589059878095357
